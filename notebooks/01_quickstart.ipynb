# %% [markdown]
# # BioMed-Exp Agent 快速开始
#
# 本笔记本演示如何使用 BioMed-Exp Agent 进行实验分析。

# %% [markdown]
# ## 1. 环境设置

# %%
# 安装依赖 (如果尚未安装)
# !pip install -e ..

# %%
import sys
sys.path.insert(0, '..')

from src.agent import create_experiment_graph, ExperimentState
from src.tools import detect_tool, track_tool

# %% [markdown]
# ## 2. 创建实验状态

# %%
# 创建实验状态
state = ExperimentState(
    user_request="分析这只小鼠在旷场中的焦虑行为",
    video_path="../data/sample_open_field.mp4"  # 替换为实际视频路径
)

print(f"实验 ID: {state.experiment_id or '待生成'}")
print(f"用户请求: {state.user_request}")

# %% [markdown]
# ## 3. 运行工作流

# %%
# 创建工作流图
graph = create_experiment_graph()

# 运行工作流 (需要实际视频)
# result = await graph.ainvoke(state)
# print(result)

# %% [markdown]
# ## 4. 查看结果

# %%
# 查看指标
# if result.metrics:
#     print("实验指标:")
#     for key, value in result.metrics.items():
#         print(f"  {key}: {value}")
